# %% [markdown]
# ## EDA on Boston_Tea_House_Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('HousingData.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296  \
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [raw]
# CRIM    : Per capita crime rate by town.
# ZN      : Proportion of residential land zoned for lots larger than 25,000 square feet.
# INDUS   : Proportion of non-retail business acres per town.
# CHAS    : Charles River dummy variable (1 if the tract bounds the river; 0 otherwise).
# NOX     : Nitric oxides concentration (parts per 10 million).
# RM      : Average number of rooms per dwelling.
# AGE     : Proportion of owner-occupied units built before 1940.
# DIS     : Weighted distances to five Boston employment centers.
# RAD     : Index of accessibility to radial highways.
# TAX     : Full-value property tax rate per $10,000.
# PTRATIO : Pupil-teacher ratio by town.
# B       : 1000(Bk - 0.63)^2, where Bk is the proportion of Black individuals by town.
# LSTAT   : Percentage of lower status of the population.
# MEDV    : Median value of owner-occupied homes in $1000s (the target variable).

# %%
df.shape
# Out:
# (506, 14)

# %%
df.sample(10)
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX
# 329   0.06724   0.0   3.24   0.0  0.460  6.333  17.2  5.2146    4  430  \
# 478  10.23300   0.0  18.10   0.0  0.614  6.185  96.7  2.1705   24  666
# 268   0.54050  20.0   3.97   0.0  0.575  7.470  52.6  2.8720    5  264
# 251   0.21409  22.0   5.86   0.0  0.431  6.438   8.9  7.3967    7  330
# 34    1.61282   0.0   8.14   0.0  0.538  6.096  96.9  3.7598    4  307
# 217   0.07013   0.0  13.89   0.0  0.550  6.642  85.1  3.4211    5  276
# 483   2.81838   0.0  18.10   0.0  0.532  5.762  40.3  4.0983   24  666
# 165   2.92400   0.0  19.58   0.0  0.605  6.101  93.0  2.2834    5  403
# 286   0.01965  80.0   1.76   0.0  0.385  6.230   NaN  9.0892    1  241
# 300   0.04417  70.0   2.24   0.0  0.400  6.871  47.4  7.8278    5  358
#
#      PTRATIO       B  LSTAT  MEDV
# 329     16.9  375.21   7.34  22.6
# 478     20.2  379.70  18.03  14.6
# 268     13.0  390.30   3.16  43.5
# 251     19.1  377.07   3.59  24.8
# ...

# %%
df['CHAS'].value_counts() # catgorical clumn
# Out:
# CHAS
# 0.0    452
# 1.0     34
# Name: count, dtype: int64

# %%
df['RAD'].value_counts() # catgorical clumn
# Out:
# RAD
# 24    132
# 5     115
# 4     110
# 3      38
# 6      26
# 2      24
# 8      24
# 1      20
# 7      17
# Name: count, dtype: int64

# %%
# except 'CHAS' & 'RAD' emaining all other are numerical columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df['CHAS']= df['CHAS'].astype('category')
df['RAD']=df['RAD'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    category
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    category
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: category(2), float64(11), int64(1)
# memory usage: 49.0 KB

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
# visual representation of of missing numbers
import missingno
missingno.matrix(df)
# Out:
# <Axes: >

# %%
# pd.set_option('display.max_rows',None)

# %%
sns.boxplot(x='CRIM',data=df)
# Out:
# <Axes: xlabel='CRIM'>

# %%
crim_median = df['CRIM'].median()
crim_median
# Out:
# 0.253715

# %%
df['CRIM'].fillna(crim_median,inplace=True)

# %%
df['CRIM'].isnull().sum()
# Out:
# 0

# %%
sns.boxplot(x='ZN',data=df)
# Out:
# <Axes: xlabel='ZN'>

# %%
df['ZN'].fillna(df['ZN'].median(),inplace=True)

# %%
df['ZN'].isnull().sum()
# Out:
# 0

# %%
sns.boxplot(x='INDUS',data=df)
# Out:
# <Axes: xlabel='INDUS'>

# %%
df['INDUS'].fillna(df['INDUS'].mean(),inplace=True)
df['INDUS'].isnull().sum()
# Out:
# 0

# %%
df['CHAS'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['CHAS'].fillna(0.0,inplace=True)
df['CHAS'].isnull().sum()
# Out:
# 0

# %%
sns.boxplot(x=df['AGE'],data=df)
# Out:
# <Axes: xlabel='AGE'>

# %%
df['AGE'].fillna(df['AGE'].mean(),inplace=True)
df['AGE'].isna().sum()
# Out:
# 0

# %%
sns.boxplot(x=df['LSTAT'],data=df)
# Out:
# <Axes: xlabel='LSTAT'>

# %%
df['LSTAT'].fillna(df['LSTAT'].median(),inplace=True)
df['LSTAT'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
# visual representation of missing numbers after imputaion
import missingno
missingno.matrix(df)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    category
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    category
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: category(2), float64(11), int64(1)
# memory usage: 49.0 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000  \
# mean     3.479140   10.768775   11.083992    0.554695    6.284634   68.518519
# std      8.570832   23.025124    6.699165    0.115878    0.702617   27.439466
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.083235    0.000000    5.190000    0.449000    5.885500   45.925000
# 50%      0.253715    0.000000    9.900000    0.538000    6.208500   74.450000
# 75%      2.808720    0.000000   18.100000    0.624000    6.623500   93.575000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               DIS         TAX     PTRATIO           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043  408.237154   18.455534  356.674032   12.664625   22.532806
# ...

# %% [markdown]
# ###### univariate analysis

# %%
# MEDV - Median Value of owner-Ocuupied Homes (Target Variable)

sns.distplot(df['MEDV'], label='Skewness :%.2f'%(df['MEDV'].skew()))
plt.legend(loc='best')
plt.title('Median Value of Owner-occumpied Homes Distribtion')
# Out:
# Text(0.5, 1.0, 'Median Value of Owner-occumpied Homes Distribtion')

# %% [markdown]
# distribution is close to normal distribution with a slight skewness

# %%
log_data = np.log(df['MEDV'])
valid_data = log_data[log_data>0]

std = (valid_data - np.mean(valid_data))/ np.std(valid_data)


sns.distplot(std ,label='Skewness :%.2f'%(std.skew()) )
plt.legend(loc='best')
plt.title('Median Value of Owner-occumpied Homes Distribtion')
# Out:
# Text(0.5, 1.0, 'Median Value of Owner-occumpied Homes Distribtion')

# %%
# CRIM (Per Caipta Crime Rate by Town) Column

sns.distplot(df['CRIM'],label='Skewness :%.2f'%(df['CRIM'].skew()) )
plt.legend(loc='best')
plt.title('Per Capita Crime Rate by Town')
# Out:
# Text(0.5, 1.0, 'Per Capita Crime Rate by Town')

# %% [markdown]
#  there is a high degree of skewness in the distribution

# %%
# adding constant 
# data_with_const = 1e-10 + df['CRIM'] 

# log transformation
# log_data=np.log(data_with_const)

# handle nan or infinite values
# valid_data = pd.to_numeric(log_data)
# valid_data = np.nan_to_num(log_data)

# handle negative or zero values
log_data = np.log(df['CRIM'])
valid_data = log_data[log_data>0]

std = (valid_data - np.mean(valid_data))/ np.std(valid_data)


sns.distplot(std ,label='Skewness :%.2f'%(std.skew()) )
plt.legend(loc='best')
plt.title('Per Capita Crime Rate by Town')
# Out:
# Text(0.5, 1.0, 'Per Capita Crime Rate by Town')

# %% [markdown]
# Distribution is close to normal distribution

# %%
# ZN - Proportion of Residential Land Zone

sns.distplot(df['ZN'], label='Skewness :%.2f'%(df['ZN'].skew()))
plt.legend(loc='best')
plt.title('Proportion of Residential Land Zone')
# Out:
# Text(0.5, 1.0, 'Proportion of Residential Land Zone')

# %% [markdown]
#  there is a high degree of skewness in the distribution of the column - ZN

# %%
log_data = np.log(df['ZN'])
valid_data = log_data[log_data>0]

std = (valid_data - np.mean(valid_data))/ np.std(valid_data)


sns.distplot(std ,label='Skewness :%.2f'%(std.skew()) )
plt.legend(loc='best')
plt.title('Proportion of Residential Land Zone')
# Out:
# Text(0.5, 1.0, 'Proportion of Residential Land Zone')

# %% [markdown]
# Distribution is close to normal distribution

# %%
# INDUS - Proportion of non retail business acres per Town

sns.distplot(df['INDUS'], label='Skewnes :%.2f'%(df['INDUS'].skew()))
plt.legend(loc='best')
plt.title('Proportion of Non-retail Business Acres Per Town')
# Out:
# Text(0.5, 1.0, 'Proportion of Non-retail Business Acres Per Town')

# %% [markdown]
# we can see that there are 2 modes for the column - INDUS.

# %%
log_data = np.log(df['INDUS'])
valid_data = log_data[log_data>0]

# adding constant 
# data_with_const = 1e-10 + df['INDUS'] 

# log transformation
# log_data=np.log(data_with_const)

# handle nan or infinite values
# valid_data = pd.to_numeric(log_data)
# valid_data = np.nan_to_num(log_data)


std = (valid_data - np.mean(valid_data))/ np.std(valid_data)


sns.distplot(std ,label='Skewness :%.2f'%(std.skew()) )
plt.legend(loc='best')
plt.title('Proportion of Non-retail Business Acres Per Town')
# Out:
# Text(0.5, 1.0, 'Proportion of Non-retail Business Acres Per Town')

# %%
# NOX - Nitric Oxide Concentration 

sns.distplot(df['NOX'], label='Skewness :%.2f'%(df['NOX'].skew()))
plt.legend(loc='best')
plt.title('Nitric Oxide Concentration')
# Out:
# Text(0.5, 1.0, 'Nitric Oxide Concentration')

# %% [markdown]
# above distribution is less degree of skewness

# %%
log_data = np.log(df['NOX'])
# valid_data = log_data[log_data>0]

std = (log_data - np.mean(log_data))/ np.std(log_data)


sns.distplot(std ,label='Skewness :%.2f'%(std.skew()) )
plt.legend(loc='best')
plt.title('Nitric Oxide Concentration')
# Out:
# Text(0.5, 1.0, 'Nitric Oxide Concentration')

# %%
# RM - Average number of rooms per Dwelling

sns.distplot(df['RM'], label='Skewness :%.2f'%(df['RM'].skew()))
plt.legend(loc='best')
plt.title('Average number of rooms per dwelling')
# Out:
# Text(0.5, 1.0, 'Average number of rooms per dwelling')

# %%
# AGE - Proportion of owner occupied units

sns.distplot(df['AGE'], label='Skewness :%.2f'%(df['AGE'].skew()))
plt.legend(loc='best')
plt.title('Proportion of owner occupied units')
# Out:
# Text(0.5, 1.0, 'Proportion of owner occupied units')

# %% [markdown]
#  distribution is slightly left skewed

# %%
# DIS - Weighted Distances Distribution

sns.distplot(df['DIS'], label='Skewness :%.2f'%(df['DIS'].skew()))
plt.legend(loc='best')
plt.title('Weighted Distances Distribution')
# Out:
# Text(0.5, 1.0, 'Weighted Distances Distribution')

# %% [markdown]
# distribution is slightly right skewed with a slight degree of skewness

# %%
log_data = np.log(df['DIS'])
# valid_data = log_data[log_data>0]

std = (log_data - np.mean(log_data))/ np.std(log_data)


sns.distplot(std ,label='Skewness :%.2f'%(std.skew()) )
plt.legend(loc='best')
plt.title('Weighted Distances Distribution')
# Out:
# Text(0.5, 1.0, 'Weighted Distances Distribution')

# %% [markdown]
# NOW DISTRIBUTION IS NORMAL DISTRIBUTION

# %%
# TAX - Full value Property Tax 

sns.distplot(df['TAX'], label='Skewness :%.2f'%(df['TAX'].skew()))
plt.legend(loc='best')
plt.title('Full value Property Tax Distribution')
# Out:
# Text(0.5, 1.0, 'Full value Property Tax Distribution')

# %% [markdown]
# there are 2 modes for the column

# %%
# PTRATIO - Pupil Teacher Ratio By Town

sns.distplot(df['PTRATIO'], label = 'Skewness: %.2f'%(df['PTRATIO'].skew()))
plt.legend(loc = 'best')
plt.title('Pupil Teacher Ratio By Town')
# Out:
# Text(0.5, 1.0, 'Pupil Teacher Ratio By Town')

# %% [markdown]
# distribution is slightly left skewed

# %%
# B - Proportion of Blacks By Town

sns.distplot(df['B'], label = 'Skewness: %.2f'%(df['B'].skew()))
plt.legend(loc = 'best')
plt.title('Proportion of Blacks By Town')
# Out:
# Text(0.5, 1.0, 'Proportion of Blacks By Town')

# %% [markdown]
# distribution is highly left skewed

# %%
# LSTAT - Distribution of the lower status of the population


sns.distplot(df['LSTAT'], label = 'Skewness: %.2f'%(df['LSTAT'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the Lower Status of the Population')
# Out:
# Text(0.5, 1.0, 'Distribution of the Lower Status of the Population')

# %%
log_data = np.log(df['LSTAT'])
# valid_data = log_data[log_data>0]

std = (log_data - np.mean(log_data))/ np.std(log_data)


sns.distplot(std ,label='Skewness :%.2f'%(std.skew()) )
plt.legend(loc='best')
plt.title('Weighted Distances Distribution')
# Out:
# Text(0.5, 1.0, 'Weighted Distances Distribution')

# %%
# CHAS - Charles River dummy variable (1 if the tract bounds the river; 0 otherwise)

df['CHAS'].value_counts()
# Out:
# CHAS
# 0.0    472
# 1.0     34
# Name: count, dtype: int64

# %%
df['CHAS'].value_counts().plot(kind='bar',)
# Out:
# <Axes: xlabel='CHAS'>

# %%
# RAD - Index of accessibility to radial highways.

rad_count = df['RAD'].value_counts()
rad_count
# Out:
# RAD
# 24    132
# 5     115
# 4     110
# 3      38
# 6      26
# 2      24
# 8      24
# 1      20
# 7      17
# Name: count, dtype: int64

# %%
sns.barplot(x=rad_count.index, y=rad_count.values)
plt.title('value counts of the RAD')
plt.ylabel('Number of Occurrences')
plt.xlabel('RAD')
# Out:
# Text(0.5, 0, 'RAD')

# %%
for i in df.columns:
    plt.figure(figsize=(7, 4))
    sns.histplot(data=df, x=i, kde = True)
    plt.show()

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE
# CRIM     1.000000 -0.185359  0.392063 -0.055585  0.410971 -0.220045  0.346395  \
# ZN      -0.185359  1.000000 -0.507800 -0.032992 -0.498619  0.312295 -0.534831
# INDUS    0.392063 -0.507800  1.000000  0.054172  0.740965 -0.381457  0.614592
# CHAS    -0.055585 -0.032992  0.054172  1.000000  0.070867  0.106797  0.073549
# NOX      0.410971 -0.498619  0.740965  0.070867  1.000000 -0.302188  0.711461
# RM      -0.220045  0.312295 -0.381457  0.106797 -0.302188  1.000000 -0.241351
# AGE      0.346395 -0.534831  0.614592  0.073549  0.711461 -0.241351  1.000000
# DIS     -0.366025  0.632428 -0.699639 -0.092318 -0.769230  0.205246 -0.724353
# RAD      0.601224 -0.300061  0.593176 -0.003339  0.611441 -0.209847  0.449989
# TAX      0.560469 -0.304385  0.716062 -0.035822  0.668023 -0.292048  0.500589
# PTRATIO  0.277964 -0.394622  0.384806 -0.109451  0.188933 -0.355501  0.262723
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ###### Bivariate Analysis

# %%
# MEDV VS CHAS - Mean value per CHAS(1 if the tract bounds the river; 0 otherwise)

mean_sales_price = df[['CHAS','MEDV']].groupby('CHAS',as_index=False).mean()
mean_sales_price
# Out:
#   CHAS       MEDV
# 0  0.0  22.079449
# 1  1.0  28.826471

# %%
sns.barplot(x=mean_sales_price['CHAS'],y=mean_sales_price['MEDV'])
plt.title('Mean Sales Price for each CHAS')
plt.ylabel('Mean Sales Price')
plt.xlabel('CHAS')
# Out:
# Text(0.5, 0, 'CHAS')

# %%
# MEDV vs RAD - Mean Price per RAD
mean_price_rad = df[['RAD','MEDV']].groupby('RAD', as_index=False).mean()
mean_price_rad
# Out:
#   RAD       MEDV
# 0   1  24.365000
# 1   2  26.833333
# 2   3  27.928947
# 3   4  21.387273
# 4   5  25.706957
# 5   6  20.976923
# 6   7  27.105882
# 7   8  30.358333
# 8  24  16.403788

# %%
sns.barplot(x=mean_price_rad['RAD'],y=mean_price_rad['MEDV'])
plt.title('Mean Sales Price for each RAD')
plt.xlabel('RAD')
plt.ylabel('Mean Sales Price (MEDV)')
# Out:
# Text(0, 0.5, 'Mean Sales Price (MEDV)')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD  TAX  PTRATIO
# 0  0.00632  18.0   2.31  0.0  0.538  6.575  65.2  4.0900   1  296     15.3  \
# 1  0.02731   0.0   7.07  0.0  0.469  6.421  78.9  4.9671   2  242     17.8
# 2  0.02729   0.0   7.07  0.0  0.469  7.185  61.1  4.9671   2  242     17.8
# 3  0.03237   0.0   2.18  0.0  0.458  6.998  45.8  6.0622   3  222     18.7
# 4  0.06905   0.0   2.18  0.0  0.458  7.147  54.2  6.0622   3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90  11.43  36.2

# %%
sns.scatterplot(x=df['CRIM'],y=df['NOX'],hue=df['CHAS'])
# Out:
# <Axes: xlabel='CRIM', ylabel='NOX'>

# %%
sns.scatterplot(x=df['CRIM'],y=df['AGE'],hue=df['CHAS'])
# Out:
# <Axes: xlabel='CRIM', ylabel='AGE'>

# %%
sns.scatterplot(x=df['CRIM'],y=df['TAX'],hue=df['CHAS'])
# Out:
# <Axes: xlabel='CRIM', ylabel='TAX'>

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df['DIS'],y=df['AGE'])
# Out:
# <Axes: xlabel='DIS', ylabel='AGE'>

# %%
sns.pairplot(df)
