# %% [markdown]
# # EDA on Diabetes Dataset

# %% [markdown]
# ### Univariate & Bivariate Analysis

# %% [markdown]
# ###### Univariate Data:
#
# This type of data consists of only one variable. The analysis of univariate data is thus the simplest form of analysis since the information deals with only one quantity that changes. It does not deal with causes or relationships and the main purpose of the analysis is to describe the data and find patterns that exist within it.
#
#     The example of a univariate data can be height.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# there is only one variable that is height and it is not dealing with any cause or relationship. The description of patterns found in this type of data can be made by drawing conclusions using central tendency measures (mean, median and mode), dispersion or spread of data (range, minimum, maximum, quartiles, variance and standard deviation) and by using frequency distribution tables, histograms, pie charts, frequency polygon and bar charts.

# %% [markdown]
# ###### Bivariate data :
#
# This type of data involves two different variables. The analysis of this type of data deals with causes and relationships and the analysis is done to find out the relationship among the two variables. Example of bivariate data can be temperature and ice cream sales in summer season.
#
# ![image.png](attachment:image.png)
#
# Suppose the temperature and ice cream sales are the two variables of a bivariate data(figure 2). Here, the relationship is visible from the table that temperature and sales are directly proportional to each other and thus related because as the temperature increases, the sales also increase. Thus bivariate data analysis involves comparisons, relationships, causes and explanations. These variables are often plotted on X and Y axis on the graph for better understanding of data and one of these variables is independent while the other is dependent.

# %% [markdown]
# ###### Multivariate data :
#
# When the data involves three or more variables, it is categorized under multivariate.
#
# Example of this type of data is suppose an advertiser wants to compare the popularity of four advertisements on a website, then their click rates could be measured for both men and women and relationships between variables can then be examined. It is similar to bivariate but contains more than one dependent variable. The ways to perform analysis on this data depends on the goals to be achieved.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Univariate Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            6      148             72             35        0  33.6  \
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin
# count   768.000000  768.000000     768.000000     768.000000  768.000000  \
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ### Col 1 - Pregnancies
#
# This is numerical data, so we can use below listed graphs for numerical data
#
#     1. hist plot (matplotlib)
#     2. distplot (seaborn)
#     3. boxplot (seaborn)

# %%
df['Pregnancies'].value_counts()
# Out:
# Pregnancies
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: count, dtype: int64

# %%
df['Pregnancies'].unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14],
#       dtype=int64)

# %%
df['Pregnancies'].nunique()
# Out:
# 17

# %%
df['Pregnancies'].isnull().sum()
# Out:
# 0

# %%
df['Pregnancies'].describe()
# Out:
# count    768.000000
# mean       3.845052
# std        3.369578
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       17.000000
# Name: Pregnancies, dtype: float64

# %%
plt.hist(df['Pregnancies'])
# Out:
# (array([246., 178., 125.,  50.,  83.,  52.,  11.,  19.,   3.,   1.]),
#  array([ 0. ,  1.7,  3.4,  5.1,  6.8,  8.5, 10.2, 11.9, 13.6, 15.3, 17. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['Pregnancies'])
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_29928\2719533762.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Pregnancies'])
# <Axes: xlabel='Pregnancies', ylabel='Density'>

# %%
sns.boxplot(df['Pregnancies'])
# Out:
# <Axes: >

# %% [markdown]
# ### Col 2 - Glucose
#
# This is numerical data, so we can use below listed graphs for numerical data
#
#     1. hist plot (matplotlib)
#     2. distplot (seaborn)
#     3. boxplot (seaborn)

# %%
df['Glucose'].value_counts()
# Out:
# Glucose
# 99     17
# 100    17
# 111    14
# 129    14
# 125    14
#        ..
# 191     1
# 177     1
# 44      1
# 62      1
# 190     1
# Name: count, Length: 136, dtype: int64

# %%
df['Glucose'].isnull().sum()
# Out:
# 0

# %%
df['Glucose'].unique()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79,   0,  62, 131, 112, 113,  74,  83, 136,
#         80, 123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160,
#        124, 162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188,
#        152, 104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,
#         91, 165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98,
#        127,  82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174,
#        199,  56, 169, 149,  65, 190], dtype=int64)

# %%
df['Glucose'].nunique()
# Out:
# 136

# %%
df['Glucose'].describe()
# Out:
# count    768.000000
# mean     120.894531
# std       31.972618
# min        0.000000
# 25%       99.000000
# 50%      117.000000
# 75%      140.250000
# max      199.000000
# Name: Glucose, dtype: float64

# %%
plt.hist(df['Glucose'],bins=20)
# Out:
# (array([  5.,   0.,   0.,   0.,   1.,   3.,   7.,  25.,  63.,  93., 117.,
#          94., 102.,  61.,  54.,  41.,  31.,  25.,  28.,  18.]),
#  array([  0.  ,   9.95,  19.9 ,  29.85,  39.8 ,  49.75,  59.7 ,  69.65,
#          79.6 ,  89.55,  99.5 , 109.45, 119.4 , 129.35, 139.3 , 149.25,
#         159.2 , 169.15, 179.1 , 189.05, 199.  ]),
#  <BarContainer object of 20 artists>)

# %%
sns.distplot(df['Glucose'])
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_29928\2512680699.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Glucose'])
# <Axes: xlabel='Glucose', ylabel='Density'>

# %%
sns.boxplot(df['Glucose'])
# Out:
# <Axes: >

# %% [markdown]
# ### Col 3 - BloodPressure
#
# This is numerical data, so we can use below listed graphs for numerical data
#
# 1. hist plot (matplotlib)
# 2. distplot (seaborn)
# 3. boxplot (seaborn)

# %%
df['BloodPressure'].value_counts()
# Out:
# BloodPressure
# 70     57
# 74     52
# 78     45
# 68     45
# 72     44
# 64     43
# 80     40
# 76     39
# 60     37
# 0      35
# 62     34
# 66     30
# 82     30
# 88     25
# 84     23
# 90     22
# 86     21
# 58     21
# 50     13
# 56     12
# 52     11
# 54     11
# 75      8
# 92      8
# 65      7
# 85      6
# 94      6
# 48      5
# 96      4
# 44      4
# 100     3
# 106     3
# 98      3
# 110     3
# 55      2
# 108     2
# 104     2
# 46      2
# 30      2
# 122     1
# 95      1
# 102     1
# 61      1
# 24      1
# 38      1
# 40      1
# 114     1
# Name: count, dtype: int64

# %%
df['BloodPressure'].unique()
# Out:
# array([ 72,  66,  64,  40,  74,  50,   0,  70,  96,  92,  80,  60,  84,
#         30,  88,  90,  94,  76,  82,  75,  58,  78,  68, 110,  56,  62,
#         85,  86,  48,  44,  65, 108,  55, 122,  54,  52,  98, 104,  95,
#         46, 102, 100,  61,  24,  38, 106, 114], dtype=int64)

# %%
df['BloodPressure'].nunique()
# Out:
# 47

# %%
df['BloodPressure'].describe()
# Out:
# count    768.000000
# mean      69.105469
# std       19.355807
# min        0.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %%
plt.hist(df['BloodPressure'])
# Out:
# (array([ 35.,   1.,   2.,  13., 107., 261., 243.,  87.,  14.,   5.]),
#  array([  0. ,  12.2,  24.4,  36.6,  48.8,  61. ,  73.2,  85.4,  97.6,
#         109.8, 122. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['BloodPressure'])
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_29928\52905997.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BloodPressure'])
# <Axes: xlabel='BloodPressure', ylabel='Density'>

# %%
sns.boxplot(df['BloodPressure'])
# Out:
# <Axes: >

# %% [markdown]
# ### Col 4 - SkinThickness
#
# This is numerical data, so we can use below listed graphs for numerical data
#
# 1. hist plot (matplotlib)
# 2. distplot (seaborn)
# 3. boxplot (seaborn)

# %%
df['SkinThickness']
# Out:
# 0      35
# 1      29
# 2       0
# 3      23
# 4      35
#        ..
# 763    48
# 764    27
# 765    23
# 766     0
# 767    31
# Name: SkinThickness, Length: 768, dtype: int64

# %%
df['SkinThickness'].describe()
# Out:
# count    768.000000
# mean      20.536458
# std       15.952218
# min        0.000000
# 25%        0.000000
# 50%       23.000000
# 75%       32.000000
# max       99.000000
# Name: SkinThickness, dtype: float64

# %%
df['SkinThickness'].unique()
# Out:
# array([35, 29,  0, 23, 32, 45, 19, 47, 38, 30, 41, 33, 26, 15, 36, 11, 31,
#        37, 42, 25, 18, 24, 39, 27, 21, 34, 10, 60, 13, 20, 22, 28, 54, 40,
#        51, 56, 14, 17, 50, 44, 12, 46, 16,  7, 52, 43, 48,  8, 49, 63, 99],
#       dtype=int64)

# %%
df['SkinThickness'].nunique()
# Out:
# 51

# %%
plt.hist(df['SkinThickness'])
# Out:
# (array([231., 107., 165., 175.,  78.,   9.,   2.,   0.,   0.,   1.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['SkinThickness'])
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_29928\1244122692.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SkinThickness'])
# <Axes: xlabel='SkinThickness', ylabel='Density'>

# %%
sns.boxplot(df['SkinThickness'])
# Out:
# <Axes: >

# %% [markdown]
# ### Col 5 - Insulin
#
# This is numerical data, so we can use below listed graphs for numerical data
#
# 1. hist plot (matplotlib)
# 2. distplot (seaborn)
# 3. boxplot (seaborn)

# %%
df['Insulin']
# Out:
# 0        0
# 1        0
# 2        0
# 3       94
# 4      168
#       ...
# 763    180
# 764      0
# 765    112
# 766      0
# 767      0
# Name: Insulin, Length: 768, dtype: int64

# %%
df['Insulin'].unique()
# Out:
# array([  0,  94, 168,  88, 543, 846, 175, 230,  83,  96, 235, 146, 115,
#        140, 110, 245,  54, 192, 207,  70, 240,  82,  36,  23, 300, 342,
#        304, 142, 128,  38, 100,  90, 270,  71, 125, 176,  48,  64, 228,
#         76, 220,  40, 152,  18, 135, 495,  37,  51,  99, 145, 225,  49,
#         50,  92, 325,  63, 284, 119, 204, 155, 485,  53, 114, 105, 285,
#        156,  78, 130,  55,  58, 160, 210, 318,  44, 190, 280,  87, 271,
#        129, 120, 478,  56,  32, 744, 370,  45, 194, 680, 402, 258, 375,
#        150,  67,  57, 116, 278, 122, 545,  75,  74, 182, 360, 215, 184,
#         42, 132, 148, 180, 205,  85, 231,  29,  68,  52, 255, 171,  73,
#        108,  43, 167, 249, 293,  66, 465,  89, 158,  84,  72,  59,  81,
#        196, 415, 275, 165, 579, 310,  61, 474, 170, 277,  60,  14,  95,
#        237, 191, 328, 250, 480, 265, 193,  79,  86, 326, 188, 106,  65,
#        166, 274,  77, 126, 330, 600, 185,  25,  41, 272, 321, 144,  15,
# ...

# %%
df['Insulin'].nunique()
# Out:
# 186

# %%
df['Insulin'].describe()
# Out:
# count    768.000000
# mean      79.799479
# std      115.244002
# min        0.000000
# 25%        0.000000
# 50%       30.500000
# 75%      127.250000
# max      846.000000
# Name: Insulin, dtype: float64

# %%
plt.hist(df['Insulin'])
# Out:
# (array([487., 155.,  70.,  30.,   8.,   9.,   5.,   1.,   2.,   1.]),
#  array([  0. ,  84.6, 169.2, 253.8, 338.4, 423. , 507.6, 592.2, 676.8,
#         761.4, 846. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['Insulin'])
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_29928\1526206684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Insulin'])
# <Axes: xlabel='Insulin', ylabel='Density'>

# %%
sns.boxplot(df['Insulin'])
# Out:
# <Axes: >

# %% [markdown]
# ### Col 6 - BMI
#
# This is numerical data, so we can use below listed graphs for numerical data
#
# 1. hist plot (matplotlib)
# 2. distplot (seaborn)
# 3. boxplot (seaborn)

# %%
df['BMI']
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
df['BMI'].unique()
# Out:
# array([33.6, 26.6, 23.3, 28.1, 43.1, 25.6, 31. , 35.3, 30.5,  0. , 37.6,
#        38. , 27.1, 30.1, 25.8, 30. , 45.8, 29.6, 43.3, 34.6, 39.3, 35.4,
#        39.8, 29. , 36.6, 31.1, 39.4, 23.2, 22.2, 34.1, 36. , 31.6, 24.8,
#        19.9, 27.6, 24. , 33.2, 32.9, 38.2, 37.1, 34. , 40.2, 22.7, 45.4,
#        27.4, 42. , 29.7, 28. , 39.1, 19.4, 24.2, 24.4, 33.7, 34.7, 23. ,
#        37.7, 46.8, 40.5, 41.5, 25. , 25.4, 32.8, 32.5, 42.7, 19.6, 28.9,
#        28.6, 43.4, 35.1, 32. , 24.7, 32.6, 43.2, 22.4, 29.3, 24.6, 48.8,
#        32.4, 38.5, 26.5, 19.1, 46.7, 23.8, 33.9, 20.4, 28.7, 49.7, 39. ,
#        26.1, 22.5, 39.6, 29.5, 34.3, 37.4, 33.3, 31.2, 28.2, 53.2, 34.2,
#        26.8, 55. , 42.9, 34.5, 27.9, 38.3, 21.1, 33.8, 30.8, 36.9, 39.5,
#        27.3, 21.9, 40.6, 47.9, 50. , 25.2, 40.9, 37.2, 44.2, 29.9, 31.9,
#        28.4, 43.5, 32.7, 67.1, 45. , 34.9, 27.7, 35.9, 22.6, 33.1, 30.4,
#        52.3, 24.3, 22.9, 34.8, 30.9, 40.1, 23.9, 37.5, 35.5, 42.8, 42.6,
# ...

# %%
df['BMI'].nunique()
# Out:
# 248

# %%
df['BMI'].describe()
# Out:
# count    768.000000
# mean      31.992578
# std        7.884160
# min        0.000000
# 25%       27.300000
# 50%       32.000000
# 75%       36.600000
# max       67.100000
# Name: BMI, dtype: float64

# %%
plt.hist(df['BMI'])
# Out:
# (array([ 11.,   0.,  15., 156., 268., 224.,  78.,  12.,   3.,   1.]),
#  array([ 0.  ,  6.71, 13.42, 20.13, 26.84, 33.55, 40.26, 46.97, 53.68,
#         60.39, 67.1 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['BMI'])
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_29928\4107119561.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BMI'])
# <Axes: xlabel='BMI', ylabel='Density'>

# %%
sns.boxplot(df['BMI'])
# Out:
# <Axes: >

# %% [markdown]
# ### Col 7 - DiabetesPedigreeFunction
#
# This is numerical data, so we can use below listed graphs for numerical data
#
# 1. hist plot (matplotlib)
# 2. distplot (seaborn)
# 3. boxplot (seaborn)

# %%
df['DiabetesPedigreeFunction']
# Out:
# 0      0.627
# 1      0.351
# 2      0.672
# 3      0.167
# 4      2.288
#        ...
# 763    0.171
# 764    0.340
# 765    0.245
# 766    0.349
# 767    0.315
# Name: DiabetesPedigreeFunction, Length: 768, dtype: float64

# %%
df['DiabetesPedigreeFunction'].unique()
# Out:
# array([0.627, 0.351, 0.672, 0.167, 2.288, 0.201, 0.248, 0.134, 0.158,
#        0.232, 0.191, 0.537, 1.441, 0.398, 0.587, 0.484, 0.551, 0.254,
#        0.183, 0.529, 0.704, 0.388, 0.451, 0.263, 0.205, 0.257, 0.487,
#        0.245, 0.337, 0.546, 0.851, 0.267, 0.188, 0.512, 0.966, 0.42 ,
#        0.665, 0.503, 1.39 , 0.271, 0.696, 0.235, 0.721, 0.294, 1.893,
#        0.564, 0.586, 0.344, 0.305, 0.491, 0.526, 0.342, 0.467, 0.718,
#        0.962, 1.781, 0.173, 0.304, 0.27 , 0.699, 0.258, 0.203, 0.855,
#        0.845, 0.334, 0.189, 0.867, 0.411, 0.583, 0.231, 0.396, 0.14 ,
#        0.391, 0.37 , 0.307, 0.102, 0.767, 0.237, 0.227, 0.698, 0.178,
#        0.324, 0.153, 0.165, 0.443, 0.261, 0.277, 0.761, 0.255, 0.13 ,
#        0.323, 0.356, 0.325, 1.222, 0.179, 0.262, 0.283, 0.93 , 0.801,
#        0.207, 0.287, 0.336, 0.247, 0.199, 0.543, 0.192, 0.588, 0.539,
#        0.22 , 0.654, 0.223, 0.759, 0.26 , 0.404, 0.186, 0.278, 0.496,
# ...

# %%
df['DiabetesPedigreeFunction'].nunique()
# Out:
# 517

# %%
df['DiabetesPedigreeFunction'].describe()
# Out:
# count    768.000000
# mean       0.471876
# std        0.331329
# min        0.078000
# 25%        0.243750
# 50%        0.372500
# 75%        0.626250
# max        2.420000
# Name: DiabetesPedigreeFunction, dtype: float64

# %%
plt.hist(df['DiabetesPedigreeFunction'])
# Out:
# (array([318., 206., 136.,  58.,  25.,  15.,   3.,   3.,   1.,   3.]),
#  array([0.078 , 0.3122, 0.5464, 0.7806, 1.0148, 1.249 , 1.4832, 1.7174,
#         1.9516, 2.1858, 2.42  ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['DiabetesPedigreeFunction'])
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_29928\2428625138.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['DiabetesPedigreeFunction'])
# <Axes: xlabel='DiabetesPedigreeFunction', ylabel='Density'>

# %%
sns.boxplot(df['DiabetesPedigreeFunction'])
# Out:
# <Axes: >

# %% [markdown]
# ### Col 8 - Age
#
# This is numerical data, so we can use below listed graphs for numerical data
#
# 1. hist plot (matplotlib)
# 2. distplot (seaborn)
# 3. boxplot (seaborn)

# %%
df['Age']
# Out:
# 0      50
# 1      31
# 2      32
# 3      21
# 4      33
#        ..
# 763    63
# 764    27
# 765    30
# 766    47
# 767    23
# Name: Age, Length: 768, dtype: int64

# %%
df['Age'].unique()
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 34, 57, 59, 51, 27, 41, 43,
#        22, 38, 60, 28, 45, 35, 46, 56, 37, 48, 40, 25, 24, 58, 42, 44, 39,
#        36, 23, 61, 69, 62, 55, 65, 47, 52, 66, 49, 63, 67, 72, 81, 64, 70,
#        68], dtype=int64)

# %%
df['Age'].nunique()
# Out:
# 52

# %%
df['Age'].describe()
# Out:
# count    768.000000
# mean      33.240885
# std       11.760232
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       41.000000
# max       81.000000
# Name: Age, dtype: float64

# %%
plt.hist(df['Age'])
# Out:
# (array([300., 157.,  92.,  86.,  52.,  34.,  26.,  16.,   4.,   1.]),
#  array([21., 27., 33., 39., 45., 51., 57., 63., 69., 75., 81.]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_29928\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %% [markdown]
# ### Col 9 - Outcome
#
# This is categorical data, so we can use below listed graphs for numerical data
#
# 1. count plot (seaborn)
# 2. pie plot (seaborn)

# %%
df['Outcome']
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
df['Outcome'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['Outcome'].nunique()
# Out:
# 2

# %%
df['Outcome'].describe()
# Out:
# count    768.000000
# mean       0.348958
# std        0.476951
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Outcome, dtype: float64

# %%
sns.countplot(x='Outcome',data=df)
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
df['Outcome'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Bivariate & Multivariate Analysis

# %% [markdown]
# The analysis depened on data type (numerical or catagorical):
#
# For visualization below tricks:
#
# ##### 1. Numerical - Numerical :
#     a. scatterplot
#     b. Lineplot
# ##### 2. Numerical - Categorical
#     a. barplot
#     b. boxplot
#     c. distplot
# ##### 3. Catagorical - Catagorical :
#     a. HeatMap
#     b. clustermap
# ##### 4. Numerical - Numerical - Numerical - Categorical -  Catagorical - Catagorical
#     a. Pairplot

# %% [markdown]
# ### Numerical - Numerical

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            6      148             72             35        0  33.6  \
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
sns.scatterplot(x=df['Pregnancies'],y=df['Glucose'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Glucose'>

# %%
sns.lineplot(x='Pregnancies', y='Glucose',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Glucose'>

# %%
sns.scatterplot(x=df['Pregnancies'],y=df['BloodPressure'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='Pregnancies', ylabel='BloodPressure'>

# %%
sns.lineplot(x='Pregnancies', y='BloodPressure',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='BloodPressure'>

# %%
sns.scatterplot(x=df['Pregnancies'],y=df['SkinThickness'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='Pregnancies', ylabel='SkinThickness'>

# %%
sns.lineplot(x='Pregnancies',y='SkinThickness',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='SkinThickness'>

# %%
sns.scatterplot(x=df['Pregnancies'],y=df['Insulin'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Insulin'>

# %%
sns.lineplot(x='Pregnancies',y='Insulin',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Insulin'>

# %%
sns.scatterplot(x=df['Pregnancies'],y=df['BMI'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='Pregnancies', ylabel='BMI'>

# %%
sns.lineplot(x='Pregnancies',y='BMI',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='BMI'>

# %%
sns.scatterplot(x=df['Pregnancies'],y=df['DiabetesPedigreeFunction'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='Pregnancies', ylabel='DiabetesPedigreeFunction'>

# %%
sns.lineplot(x='Pregnancies',y='DiabetesPedigreeFunction',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='DiabetesPedigreeFunction'>

# %%
sns.scatterplot(x=df['Pregnancies'],y=df['Age'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Age'>

# %%
sns.lineplot(x='Pregnancies',y='Age',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Age'>

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            6      148             72             35        0  33.6  \
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
sns.scatterplot(x=df['Glucose'],y=df['BloodPressure'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='Glucose', ylabel='BloodPressure'>

# %%
sns.lineplot(x='Glucose',y='BloodPressure',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='Glucose', ylabel='BloodPressure'>

# %%
sns.scatterplot(x=df['Glucose'],y=df['SkinThickness'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='Glucose', ylabel='SkinThickness'>

# %%
sns.lineplot(x='Glucose',y='SkinThickness',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='Glucose', ylabel='SkinThickness'>

# %%
sns.scatterplot(x=df['Glucose'],y=df['Insulin'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='Glucose', ylabel='Insulin'>

# %%
sns.lineplot(x='Glucose',y='Insulin',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='Glucose', ylabel='Insulin'>

# %%
sns.scatterplot(x=df['Glucose'],y=df['BMI'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='Glucose', ylabel='BMI'>

# %%
sns.lineplot(x='Glucose',y='BMI',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='Glucose', ylabel='BMI'>

# %%
sns.scatterplot(x=df['Glucose'],y=df['DiabetesPedigreeFunction'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='Glucose', ylabel='DiabetesPedigreeFunction'>

# %%
sns.lineplot(x='Glucose',y='DiabetesPedigreeFunction',data=df, hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='Glucose', ylabel='DiabetesPedigreeFunction'>

# %%
sns.scatterplot(x=df['Glucose'],y=df['Age'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='Glucose', ylabel='Age'>

# %%
sns.lineplot(x='Glucose',y='Age',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='Glucose', ylabel='Age'>

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            6      148             72             35        0  33.6  \
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
sns.scatterplot(x=df['BloodPressure'],y=df['SkinThickness'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='BloodPressure', ylabel='SkinThickness'>

# %%
sns.lineplot(x='BloodPressure',y='SkinThickness',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='BloodPressure', ylabel='SkinThickness'>

# %%
sns.scatterplot(x=df['BloodPressure'],y=df['Insulin'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Insulin'>

# %%
sns.lineplot(x='BloodPressure',y='Insulin',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Insulin'>

# %%
sns.scatterplot(x=df['BloodPressure'],y=df['BMI'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='BloodPressure', ylabel='BMI'>

# %%
sns.lineplot(x='BloodPressure',y='BMI',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='BloodPressure', ylabel='BMI'>

# %%
sns.scatterplot(x=df['BloodPressure'],y=df['DiabetesPedigreeFunction'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='BloodPressure', ylabel='DiabetesPedigreeFunction'>

# %%
sns.lineplot(x='BloodPressure',y='DiabetesPedigreeFunction',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='BloodPressure', ylabel='DiabetesPedigreeFunction'>

# %%
sns.scatterplot(x=df['BloodPressure'],y=df['Age'],hue=df['Outcome'],style=df['Outcome'])
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Age'>

# %%
sns.lineplot(x='BloodPressure',y='Age',data=df,hue='Outcome',style='Outcome')
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Age'>
