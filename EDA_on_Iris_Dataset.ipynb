# %% [markdown]
# # EDA on Iris_Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df2=df.select_dtypes(include='number')
df2.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# Id             1.000000       0.716676     -0.397729       0.882747  \
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
sns.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 75    76            6.6           3.0            4.4           1.4  \
# 80    81            5.5           2.4            3.8           1.1
# 24    25            4.8           3.4            1.9           0.2
# 28    29            5.2           3.4            1.4           0.2
# 148  149            6.2           3.4            5.4           2.3
# 90    91            5.5           2.6            4.4           1.2
# 35    36            5.0           3.2            1.2           0.2
# 40    41            5.0           3.5            1.3           0.3
# 87    88            6.3           2.3            4.4           1.3
# 119  120            6.0           2.2            5.0           1.5
#
#              Species
# 75   Iris-versicolor
# 80   Iris-versicolor
# 24       Iris-setosa
# 28       Iris-setosa
# 148   Iris-virginica
# 90   Iris-versicolor
# 35       Iris-setosa
# 40       Iris-setosa
# 87   Iris-versicolor
# ...

# %%
# our target column is "Species" because we need result according to species only

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
sns.countplot(x='Species', data=df)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
df['Species'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# 'SepalLengthCm' column

sns.distplot(df['SepalLengthCm'])

print('Distribution Devates from symmetry :',df['SepalLengthCm'].skew())
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_24508\1411450502.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SepalLengthCm'])
# Distribution Devates from symmetry : 0.3149109566369728

# %%
sns.boxplot(df['SepalLengthCm'])
# Out:
# <Axes: >

# %%
# 'SepalWidthCm' column

sns.distplot(df['SepalWidthCm'])

print('Distribution deviates from symmetry :', df['SepalWidthCm'].skew())
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_24508\464573015.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SepalWidthCm'])
# Distribution deviates from symmetry : 0.3340526621720866

# %%
# 'PetalLengthCm' column

sns.distplot(df['PetalLengthCm'])

print(df['PetalLengthCm'].skew())
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_24508\3397956089.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['PetalLengthCm'])
# -0.27446425247378287

# %%
sns.boxplot(df['PetalLengthCm'])
# Out:
# <Axes: >

# %%
log_data=np.log(data)
# sqrt_data=np.sqrt(df['PetalLengthCm'])

# valid_data=log_data[log_data>0]
# valid_data=pd.to_numeric(df['PetalLengthCm'])


# std_data = (valid_data - np.mean(valid_data))/np.std(valid_data)

sns.distplot(log_data)
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_24508\3203163993.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(log_data)
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
# 'PetalWodth' column

sns.distplot(df['PetalWidthCm'])

print('Distribution Deviates from symmetry :',df['PetalWidthCm'].skew())
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_24508\4129110492.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['PetalWidthCm'])
# Distribution Deviates from symmetry : -0.10499656214412734

# %%
sns.boxplot(df['PetalWidthCm'])
# Out:
# <Axes: >

# %% [markdown]
# ###### Relation between Variables

# %%
# sepallength vs sepalwidth

sns.scatterplot(x=df['SepalLengthCm'],y=df['SepalWidthCm'],hue=df['Species'])
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.lineplot(x=df['SepalLengthCm'],y=df['SepalWidthCm'],hue=df['Species'])
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
# PetalLengthCm vs PetalWidthCm 

sns.scatterplot(x=df['PetalLengthCm'],y=df['PetalWidthCm'],hue=df['Species'])
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.lineplot(x=df['PetalLengthCm'],y=df['PetalWidthCm'],hue=df['Species'])
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
df.sample(3)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 23  24            5.1           3.3            1.7           0.5  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 41  42            4.5           2.3            1.3           0.3  Iris-setosa

# %%
# SepalLengthCm vs PetalLengthCm 
sns.scatterplot(x=df['SepalLengthCm'],y=df['PetalLengthCm'],hue=df['Species'])
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
# SepalWidthCm vs PetalLengthCm 
sns.scatterplot(x=df['SepalWidthCm'],y=df['PetalLengthCm'],hue=df['Species'])
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='PetalLengthCm'>

# %%
# multivariate Analysis

sns.pairplot(df,hue='Species')

# %% [markdown]
# if we want to create a new array or DataFrame filled with zeros to store aggregated results, perform calculations, or fill missing values. In such cases, we can use the existing NumPy and Pandas functions to achieve this

# %%
# other way of checking aggregated results 

df_setosa = df.loc[df['Species']=='Iris-setosa']
df_verginica = df.loc[df['Species']=='Iris-virginica']
df_versicolor = df.loc[df['Species']=='Iris-versicolor']

# %%
plt.plot(df_setosa['SepalLengthCm'],np.zeros_like(df_setosa['SepalLengthCm']),'or')
plt.plot(df_verginica['SepalLengthCm'],np.zeros_like(df_verginica['SepalLengthCm']),'oy')
plt.plot(df_versicolor['SepalLengthCm'],np.zeros_like(df_versicolor['SepalLengthCm']),'ob')
plt.xlabel('Sepal Length')
plt.show()
