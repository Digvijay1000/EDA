# %% [markdown]
# # EDA - on Titanic Dataset

# %% [markdown]
# # Univariate Analysis
#
# ##### Catagorical Data
#     1. countplot
#     2. piechart
#
# ##### Numerical Data
#     1. hist
#     2. distplot
#     3. boxplot
#
# # Bivariate / Multivariate Analysis
#
# ##### 1. Numerical - Numerical :
#     a. scatterplot
#     b. Lineplot
# ##### 2. Numerical - Categorical
#     a. barplot
#     b. boxplot
#     c. distplot
# ##### 3. Catagorical - Catagorical :
#     a. HeatMap
#     b. clustermap
# ##### 4. Numerical - Numerical - Numerical - Categorical -  Catagorical - Catagorical
#     a. Pairplot

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('titanic.csv')
df
# Out:
#       PassengerId  Survived  Pclass
# 0             1.0       0.0     3.0  \
# 1             2.0       1.0     1.0
# 2             3.0       1.0     3.0
# 3             4.0       1.0     1.0
# 4             5.0       0.0     3.0
# ...           ...       ...     ...
# 1778        887.0       0.0     2.0
# 1779        888.0       1.0     1.0
# 1780        889.0       0.0     3.0
# 1781        890.0       1.0     1.0
# 1782        891.0       0.0     3.0
#
#                                                    Name     Sex   Age  SibSp
# 0                               Braund, Mr. Owen Harris    male  22.0    1.0  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                                Heikkinen, Miss. Laina  female  26.0    0.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                              Allen, Mr. William Henry    male  35.0    0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1783 entries, 0 to 1782
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1782 non-null   float64
#  1   Survived     1782 non-null   float64
#  2   Pclass       1782 non-null   float64
#  3   Name         1782 non-null   object
#  4   Sex          1782 non-null   object
#  5   Age          1428 non-null   float64
#  6   SibSp        1782 non-null   float64
#  7   Parch        1782 non-null   float64
#  8   Ticket       1782 non-null   object
#  9   Fare         1782 non-null   float64
#  10  Cabin        408 non-null    object
#  11  Embarked     1777 non-null   object
# dtypes: float64(7), object(5)
# memory usage: 167.3+ KB

# %%
df.describe()
# Out:
#        PassengerId     Survived       Pclass          Age        SibSp
# count  1782.000000  1782.000000  1782.000000  1428.000000  1782.000000  \
# mean    446.000000     0.383838     2.308642    29.699118     0.523008
# std     257.281582     0.486456     0.835836    14.521407     1.102434
# min       1.000000     0.000000     1.000000     0.420000     0.000000
# 25%     223.250000     0.000000     2.000000    20.000000     0.000000
# 50%     446.000000     0.000000     3.000000    28.000000     0.000000
# 75%     668.750000     1.000000     3.000000    38.000000     1.000000
# max     891.000000     1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1782.000000  1782.000000
# mean      0.381594    32.204208
# std       0.805831    49.679476
# min       0.000000     0.000000
# 25%       0.000000     7.903100
# 50%       0.000000    14.454200
# 75%       0.000000    31.000000
# max       6.000000   512.329200

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0          1.0       0.0     3.0  \
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0    0.0         A/5 21171   7.2500   NaN        S
# 1    0.0          PC 17599  71.2833   C85        C
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3    0.0            113803  53.1000  C123        S
# 4    0.0            373450   8.0500   NaN        S

# %%
df['PassengerId'].value_counts() # numerical
# Out:
# PassengerId
# 1.0      2
# 599.0    2
# 588.0    2
# 589.0    2
# 590.0    2
#         ..
# 301.0    2
# 302.0    2
# 303.0    2
# 304.0    2
# 891.0    2
# Name: count, Length: 891, dtype: int64

# %%
df['Survived'].value_counts() # categorical
# Out:
# Survived
# 0.0    1098
# 1.0     684
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts() # categorical
# Out:
# Pclass
# 3.0    982
# 1.0    432
# 2.0    368
# Name: count, dtype: int64

# %%
df['Name'].value_counts() # Numerical
# Out:
# Name
# Braund, Mr. Owen Harris                     2
# Boulos, Mr. Hanna                           2
# Frolicher-Stehli, Mr. Maxmillian            2
# Gilinski, Mr. Eliezer                       2
# Murdlin, Mr. Joseph                         2
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    2
# McCoy, Mr. Bernard                          2
# Johnson, Mr. William Cahoone Jr             2
# Keane, Miss. Nora A                         2
# Dooley, Mr. Patrick                         2
# Name: count, Length: 891, dtype: int64

# %%
df[['Sex']].value_counts() # categorical
# Out:
# Sex
# male      1154
# female     628
# Name: count, dtype: int64

# %%
df['Age'].value_counts() # Numerical
# Out:
# Age
# 24.00    60
# 22.00    54
# 18.00    52
# 19.00    50
# 28.00    50
#          ..
# 36.50     2
# 55.50     2
# 0.92      2
# 23.50     2
# 74.00     2
# Name: count, Length: 88, dtype: int64

# %%
df['SibSp'].value_counts() # Categorical
# Out:
# SibSp
# 0.0    1216
# 1.0     418
# 2.0      56
# 4.0      36
# 3.0      32
# 8.0      14
# 5.0      10
# Name: count, dtype: int64

# %%
df['Parch'].value_counts() # categrorical
# Out:
# Parch
# 0.0    1356
# 1.0     236
# 2.0     160
# 5.0      10
# 3.0      10
# 4.0       8
# 6.0       2
# Name: count, dtype: int64

# %%
df['Ticket'].value_counts() # numerical
# Out:
# Ticket
# 347082      14
# CA. 2343    14
# 1601        14
# 3101295     12
# CA 2144     12
#             ..
# 9234         2
# 19988        2
# 2693         2
# PC 17612     2
# 370376       2
# Name: count, Length: 681, dtype: int64

# %%
df['Fare'].value_counts() # numerical
# Out:
# Fare
# 8.0500     86
# 13.0000    84
# 7.8958     76
# 7.7500     68
# 26.0000    62
#            ..
# 35.0000     2
# 28.5000     2
# 6.2375      2
# 14.0000     2
# 10.5167     2
# Name: count, Length: 248, dtype: int64

# %%
df['Cabin'].value_counts() # Categorical
# Out:
# Cabin
# B96 B98        8
# G6             8
# C23 C25 C27    8
# C22 C26        6
# F33            6
#               ..
# E34            2
# C7             2
# C54            2
# E36            2
# C148           2
# Name: count, Length: 147, dtype: int64

# %%
df['Embarked'].value_counts() # catagorical
# Out:
# Embarked
# S    1287
# C     336
# Q     154
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0          1.0       0.0     3.0  \
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0    0.0         A/5 21171   7.2500   NaN        S
# 1    0.0          PC 17599  71.2833   C85        C
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3    0.0            113803  53.1000  C123        S
# 4    0.0            373450   8.0500   NaN        S

# %% [markdown]
# ### Univariate Analysis - Catagorical Data
#
#     1. piechart
#     2. countplot/barplot

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# sns.countplot(x='Survived',data=df)
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.3f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
sns.countplot(x='Pclass',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
sns.countplot(x='Sex',data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0          1.0       0.0     3.0  \
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0    0.0         A/5 21171   7.2500   NaN        S
# 1    0.0          PC 17599  71.2833   C85        C
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3    0.0            113803  53.1000  C123        S
# 4    0.0            373450   8.0500   NaN        S

# %%
df['SibSp'].value_counts().plot(kind='pie',autopct='%.01f')
# Out:
# <Axes: ylabel='count'>

# %%
df['SibSp'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SibSp'>

# %%
df['Parch'].value_counts().plot(kind='pie',autopct='%.01f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Parch'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Parch'>

# %%
sns.countplot(x='Parch',data=df)
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
df['Cabin'].value_counts().plot(kind='pie',autopct='%.01f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Cabin'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cabin'>

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%.01f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Univariate Analysis - Numeric Data
#
#     1. hist
#     2. distplot
#     3. boxplot

# %%
df['Age'].plot(kind='hist',color='hotpink')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_6712\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Fare'].plot(kind='hist',color='hotpink')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.distplot(df['Fare'])
# Out:
# C:\Users\Digvijay Mohite\AppData\Local\Temp\ipykernel_6712\3425841524.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare'])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
df['Fare'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ### Bivariaate Analysis - (Numeric-Numeric)
#
#     1. scatterplot
#     2. lineplot

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0          1.0       0.0     3.0  \
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0    0.0         A/5 21171   7.2500   NaN        S
# 1    0.0          PC 17599  71.2833   C85        C
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3    0.0            113803  53.1000  C123        S
# 4    0.0            373450   8.0500   NaN        S

# %%
plt.scatter(x=df['Age'],y=df['Fare'])
plt.xlabel('Age')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %%
sns.scatterplot(x=df['Age'],y=df['Fare'],hue=df['Survived'])
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.lineplot(x=df['Age'],y=df['Fare'])
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# ### Bivariaate Analysis - (Numeric-Catagorical)
#
#     1. barplot
#     2. boxplot
#     3. distplot

# %%
plt.box(x=df['Sex'],y=df['Age'],height=0.10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 plt.box(x=df['Sex'],y=df['Age'],height=0.10)
#
# TypeError: box() got an unexpected keyword argument 'x'
